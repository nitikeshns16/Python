# %% [markdown]
# # Electric Vehicle Data Analysis Project

# %% [markdown]
# ## Project Overview
# In this project, you will analyze a dataset related to electric vehicles (EVs). The dataset contains various features such as electric range, energy consumption, price, and other relevant attributes. Your goal is to conduct a thorough analysis to uncover meaningful insights, tell a compelling story, conduct hypothesis testing and provide actionable recommendations based on the data.
#
# ### Dataset: FEV-data-Excel.xlsx
#
# ### Dataset Overview
# Car full name: The full name or designation of the vehicle, often combining make, model, and variant.
#
# Make: The brand or manufacturer of the car.
#
# Model: The specific model or version of the car.
#
# Minimal price (gross) [PLN]: The minimum retail price of the car, in Polish złoty (PLN). Engine power [KM]: The car's engine power, measured in horsepower (KM in Polish).
#
# Maximum torque [Nm]: The peak torque the engine can produce, measured in Newton-meters (Nm).
#
# Type of brakes: The braking system used, such as disc or drum brakes.
#
# Drive type: The drivetrain configuration, like FWD (front-wheel drive), RWD (rear-wheel drive), or AWD (all-wheel drive).
#
# Battery capacity [kWh]: Total energy capacity of the car’s battery, measured in kilowatt-hours (kWh).
#
# Range (WLTP) [km]: Estimated driving range on a full charge under WLTP standards, in kilometers.
#
# Wheelbase [cm]: The distance between the front and rear axles, in centimeters. Length [cm]: The overall length of the car, in centimeters.
#
# Width [cm]: The car’s width, in centimeters.Height [cm]: The car’s height, in centimeters.
#
# Minimal empty weight [kg]: The car’s minimum weight when empty, measured in kilograms.
#
# Permissible gross weight [kg]: Maximum legally allowed weight, including passengers and cargo, in kilograms.
#
# Maximum load capacity [kg]: The maximum weight the car can carry, in kilograms.
#
# Number of seats: The number of passenger seats in the car.
#
# Number of doors: The number of doors on the car.
#
# Tire size [in]: The tire size, measured in inches.
#
# Maximum speed [kph]: The top speed of the car, in kilometers per hour.
#
# Boot capacity (VDA) [l]: Trunk or cargo space capacity, measured in liters according to VDA standards.
#
# Acceleration 0-100 kph [s]: Time taken to accelerate from 0 to 100 kilometers per hour, in seconds.
#
# Maximum DC charging power [kW]: The highest charging power supported when using a DC fast charger, in kilowatts (kW).
#
# Mean - Energy consumption [kWh/100 km]: Average energy consumption per 100 kilometers, in kilowatt-hours (kWh).
#
# ### Instructions
# ●    Use Python and libraries such as Pandas, NumPy, SciPy, Matplotlib, and any other tools you find necessary.
# ●    Focus on clear, structured code and explanations to guide readers through your thought process.
# ●    Every task requires both a coding solution and a written analysis section explaining your findings.

# %%
# Import Liabraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind

# %% [markdown]
# Task 1: A customer has a budget of 350,000 PLN and wants an EV with a minimum range of 400 km.
# a) Your task is to filter out EVs that meet these criteria.(2 Marks)
# b) Group them by the manufacturer (Make).(6 marks)
# c) Calculate the average battery capacity for each manufacturer. (8 Marks)

# %%
#Read excel file, print head
df = pd.read_excel("FEV-data-Excel.xlsx")
df.head()
# Out:
#                       Car full name  Make                        Model  \
# 0            Audi e-tron 55 quattro  Audi            e-tron 55 quattro
# 1            Audi e-tron 50 quattro  Audi            e-tron 50 quattro
# 2             Audi e-tron S quattro  Audi             e-tron S quattro
# 3  Audi e-tron Sportback 50 quattro  Audi  e-tron Sportback 50 quattro
# 4  Audi e-tron Sportback 55 quattro  Audi  e-tron Sportback 55 quattro
#
#    Minimal price (gross) [PLN]  Engine power [KM]  Maximum torque [Nm]  \
# 0                       345700                360                  664
# 1                       308400                313                  540
# 2                       414900                503                  973
# 3                       319700                313                  540
# 4                       357000                360                  664
#
#         Type of brakes Drive type  Battery capacity [kWh]  Range (WLTP) [km]  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 25 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Car full name                           53 non-null     object
#  1   Make                                    53 non-null     object
#  2   Model                                   53 non-null     object
#  3   Minimal price (gross) [PLN]             53 non-null     int64
#  4   Engine power [KM]                       53 non-null     int64
#  5   Maximum torque [Nm]                     53 non-null     int64
#  6   Type of brakes                          52 non-null     object
#  7   Drive type                              53 non-null     object
#  8   Battery capacity [kWh]                  53 non-null     float64
#  9   Range (WLTP) [km]                       53 non-null     int64
# ...

# %%
df.describe()
# Out:
#        Minimal price (gross) [PLN]  Engine power [KM]  Maximum torque [Nm]  \
# count                    53.000000          53.000000            53.000000
# mean                 246158.509434         269.773585           460.037736
# std                  149187.485190         181.298589           261.647000
# min                   82050.000000          82.000000           160.000000
# 25%                  142900.000000         136.000000           260.000000
# 50%                  178400.000000         204.000000           362.000000
# 75%                  339480.000000         372.000000           640.000000
# max                  794000.000000         772.000000          1140.000000
#
#        Battery capacity [kWh]  Range (WLTP) [km]  Wheelbase [cm]  Length [cm]  \
# count               53.000000          53.000000       53.000000    53.000000
# mean                62.366038         376.905660      273.581132   442.509434
# ...

# %%
# a) A customer has a budget of 350,000 PLN and wants an EV with a minimum range of 400 km.
# Your task is to filter out EVs that meet these criteria.(2 Marks)

filtered_rows = df[(df['Minimal price (gross) [PLN]']<= 350000) & (df['Range (WLTP) [km]']>=400)]
filtered_rows
# Out:
#                         Car full name           Make  \
# 0              Audi e-tron 55 quattro           Audi
# 8                             BMW iX3            BMW
# 15        Hyundai Kona electric 64kWh        Hyundai
# 18                   Kia e-Niro 64kWh            Kia
# 20                   Kia e-Soul 64kWh            Kia
# 22                  Mercedes-Benz EQC  Mercedes-Benz
# 39  Tesla Model 3 Standard Range Plus          Tesla
# 40           Tesla Model 3 Long Range          Tesla
# 41          Tesla Model 3 Performance          Tesla
# 47    Volkswagen ID.3 Pro Performance     Volkswagen
# 48              Volkswagen ID.3 Pro S     Volkswagen
# 49                Volkswagen ID.4 1st     Volkswagen
#
#                           Model  Minimal price (gross) [PLN]  \
# 0             e-tron 55 quattro                       345700
# 8                           iX3                       282900
# 15          Kona electric 64kWh                       178400
# ...

# %%
# b) Group them by the manufacturer (Make).(6 marks)
grouped = filtered_rows.groupby('Make')
print(grouped.size())
# Out:
# Make
# Audi             1
# BMW              1
# Hyundai          1
# Kia              2
# Mercedes-Benz    1
# Tesla            3
# Volkswagen       3
# dtype: int64

# %%
# c) Calculate the average battery capacity for each manufacturer.
grouped['Battery capacity [kWh]'].mean()
# Out:
# Make
# Audi             95.000000
# BMW              80.000000
# Hyundai          64.000000
# Kia              64.000000
# Mercedes-Benz    80.000000
# Tesla            68.000000
# Volkswagen       70.666667
# Name: Battery capacity [kWh], dtype: float64

# %%
##Task 2: You suspect some EVs have unusually high or low energy consumption. 
    
##Find the outliers in the mean - Energy consumption [kWh/100 km] column.(16 Marks)

    
# Using description checking if there is outliers getting or not
df['mean - Energy consumption [kWh/100 km]'].describe()
# Out:
# count    44.000000
# mean     18.994318
# std       4.418253
# min      13.100000
# 25%      15.600000
# 50%      17.050000
# 75%      23.500000
# max      28.200000
# Name: mean - Energy consumption [kWh/100 km], dtype: float64

# %% [markdown]
# #### From description you cannot observe any outliers in mean energy consumption column of the dataset

# %%
df['mean - Energy consumption [kWh/100 km]'].median()
# Out:
# 17.05

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x = df['mean - Energy consumption [kWh/100 km]'])
plt.show()

# %% [markdown]
# ### Another way to findout outliers we used boxplot visualisation. But, from above visualisation there no such outliers are found. All values lies in the range 12 to 28. And more frquency found in range 16 to 24.

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x = df['Minimal price (gross) [PLN]'])
plt.show()

# %% [markdown]
# ### Here there are two outliers are found the price range. On 700K and on 800K. Other values are lies in between 100K and 500K. More frequency found in range 150K tp 350K

# %%
print(df['Minimal price (gross) [PLN]'].describe())
# Out:
# count        53.000000
# mean     246158.509434
# std      149187.485190
# min       82050.000000
# 25%      142900.000000
# 50%      178400.000000
# 75%      339480.000000
# max      794000.000000
# Name: Minimal price (gross) [PLN], dtype: float64

# %%
"""Task 3: Your manager wants to know if there's a strong relationship between battery capacity and range.
a) Create a suitable plot to visualize.(8 Marks)
b) Highlight any insights.(8 Marks)"""

corr = df[['Battery capacity [kWh]','Range (WLTP) [km]']].corr()
corr
# Out:
#                         Battery capacity [kWh]  Range (WLTP) [km]
# Battery capacity [kWh]                1.000000           0.810439
# Range (WLTP) [km]                     0.810439           1.000000

# %%
sns.heatmap(corr, cmap='BrBG', annot=True)
plt.show()

# %% [markdown]
# ### From above visualisation, we can conclude that range and battery capacity are strongly rely on each other as their correlation count is 0.8

# %%
numerical_columns = df.select_dtypes(include=['int64', 'float'])
numerical_columns
# Out:
#     Minimal price (gross) [PLN]  Engine power [KM]  Maximum torque [Nm]  \
# 0                        345700                360                  664
# 1                        308400                313                  540
# 2                        414900                503                  973
# 3                        319700                313                  540
# 4                        357000                360                  664
# 5                        426200                503                  973
# 6                        169700                170                  250
# 7                        184200                184                  270
# 8                        282900                286                  400
# 9                        125000                136                  260
# 10                       159900                136                  260
# 11                       152900                136                  315
# ...

# %%
corr1 = numerical_columns.corr()
corr1
# Out:
#                                         Minimal price (gross) [PLN]  \
# Minimal price (gross) [PLN]                                1.000000
# Engine power [KM]                                          0.887146
# Maximum torque [Nm]                                        0.878673
# Battery capacity [kWh]                                     0.816513
# Range (WLTP) [km]                                          0.506311
# Wheelbase [cm]                                             0.645141
# Length [cm]                                                0.742424
# Width [cm]                                                 0.538703
# Height [cm]                                               -0.143217
# Minimal empty weight [kg]                                  0.810863
# Permissable gross weight [kg]                              0.755738
# Maximum load capacity [kg]                                 0.462807
# Number of seats                                            0.084391
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(corr1, cmap='magma', annot=True)
plt.show()

# %% [markdown]
# ### Here in the heatmap you can observe that annotations which are presented in the light color are more strongly interconnected with each other. While annotations presented in dark color are not much interconnected. You can observe the scores.

# %%
"""Task 4: Build an EV recommendation class. The class should allow users to input their budget, 
    desired range, and battery capacity. 
    The class should then return the top three EVs matching their criteria. (8+8 Marks)"""
class EVRecommendation:
    def recommended_EVS():
    
        budget = int(input('Enter your budget: '))
        desired_range = int(input('Enter your desired range: '))
        desired_battery_capacity = int(input('Enter your desired battery range: '))
        
        df1 = df[
            (df['Minimal price (gross) [PLN]'] <= budget) &
            (df['Range (WLTP) [km]'] >= desired_range) &
            (df['Battery capacity [kWh]'] >= desired_battery_capacity)
        ]
        
        df1 = df1.copy()
        
        df1['score'] = (
            1 / df1['Minimal price (gross) [PLN]'] +
            df1['Range (WLTP) [km]'] +
            df1['Battery capacity [kWh]']
        )
        
        if df1.empty:
            return 'No EV according to your criteria'
        
        top_EVS = df1.sort_values('score', ascending = False, ).head(3)
        
        return top_EVS[['Make', 'Model', 'Minimal price (gross) [PLN]', 'Range (WLTP) [km]', 'Battery capacity [kWh]']]

# %%
output = EVRecommendation
recommendation = EVRecommendation.recommended_EVS()
recommendation
# Out:
# Enter your budget: 300000
# Enter your desired range: 450
# Enter your desired battery range: 50
#           Make                Model  Minimal price (gross) [PLN]  \
# 40       Tesla   Model 3 Long Range                       235490
# 41       Tesla  Model 3 Performance                       260490
# 48  Volkswagen           ID.3 Pro S                       179990
#
#     Range (WLTP) [km]  Battery capacity [kWh]
# 40                580                    75.0
# 41                567                    75.0
# 48                549                    77.0

# %%
"""Task 5: Inferential Statistics – Hypothesis Testing: Test whether there is a significant 
difference in the average Engine power [KM] of vehicles 
manufactured by two leading manufacturers i.e. Tesla and Audi. 
What insights can you draw from the test results? 
Recommendations and Conclusion: Provide actionable insights based on your analysis. 
(Conduct a two sample t-test using ttest_ind from scipy.stats module) (16 Marks)"""
Audi_power = df[df['Make'] == 'Audi']['Engine power [KM]']
Tesla_power = df[df['Make'] == 'Tesla']['Engine power [KM]']
print(Audi_power.isnull().sum())
print(Tesla_power)
# Out:
# 0
# 39    285
# 40    372
# 41    480
# 42    525
# 43    772
# 44    525
# 45    772
# Name: Engine power [KM], dtype: int64

# %%
t_statistics, p_value = ttest_ind(Audi_power, Tesla_power)
print(t_statistics, p_value)
# Out:
# -1.7024444538261416 0.11672692675082785

# %%
alpha = 0.05  # Significance level

if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in the average engine power between Tesla and Audi vehicles.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in the average engine power between Tesla and Audi vehicles.")

# Insights and Recommendations:
if p_value < alpha:
  #If there's a significant difference, further analysis is required.
  #1. Effect size:  Determine the magnitude of difference using Cohen's d.
  #2. Explore other factors that might be influencing engine power.
  #3. Consider whether this difference matters to consumers.
  print("Further analysis is needed to understand the nature and practical significance of the difference in average engine power between the two manufacturers.")
else:
  print("The analysis does not suggest a significant difference in engine power between Tesla and Audi, based on the available data.")
  # Recommendations:
  #1. If additional factors like price or features need to be compared to support purchasing decisions, they should be investigated.
  #2. Additional data could reduce uncertainty around this conclusion.
# Out:
# Fail to reject the null hypothesis. There is no significant difference in the average engine power between Tesla and Audi vehicles.
# The analysis does not suggest a significant difference in engine power between Tesla and Audi, based on the available data.
